# %% [markdown]
# # Pandas Introduction

# %% [markdown]
# ## Reading files into DataFrames
#
# In Pandas, data is accessed through a [DataFrame](https://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe). A DataFrame is a 2D data structure where each column may contain different data types, from numeric series to complex structures. In most cases, you can think on DataFrames as _tables_.
#
# The [IO API](https://pandas.pydata.org/pandas-docs/stable/io.html) has different methods to read different formats, most common one is text-delimited files:

# %%
import pandas as pd
data = pd.read_csv("./data/goog.csv")

# %% [markdown]
# From this point we can access the data using different methods. For instance, `head(n)` will retrieve the first `n` columns:

# %%
data.head(2)
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 0  2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
# 1  2016-06-30  685.469971  692.320007  683.650024  692.099976  1590500
#
#     Adj Close
# 0  699.210022
# 1  692.099976

# %% [markdown]
# DataFrame also allows _range_ expressions, by using `[]` or `loc`.

# %%
data[5:7]
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 5  2016-06-24  675.169983  689.400024  673.450012  675.219971  4399800
# 6  2016-06-23  697.450012  701.950012  687.000000  701.869995  2157400
#
#     Adj Close
# 5  675.219971
# 6  701.869995

# %%
data.loc[5:7]
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 5  2016-06-24  675.169983  689.400024  673.450012  675.219971  4399800
# 6  2016-06-23  697.450012  701.950012  687.000000  701.869995  2157400
# 7  2016-06-22  699.059998  700.859985  693.081970  697.460022  1179300
#
#     Adj Close
# 5  675.219971
# 6  701.869995
# 7  697.460022

# %%
edge_case = pd.DataFrame({'val': ['a', 'b', 'c', 'd']}, index=[10, 20, 30, 40])
print(edge_case.loc[20:30])
# Out:
#    val
# 20   b
# 30   c

# %% [markdown]
# Single row access is done using `iloc` attribute:

# %%
data.iloc[5]
# Out:
# Date         2016-06-24
# Open         675.169983
# High         689.400024
# Low          673.450012
# Close        675.219971
# Volume          4399800
# Adj Close    675.219971
# Name: 5, dtype: object

# %%
data.iloc[5].Open
# Out:
# np.float64(675.169983)

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='str')

# %% [markdown]
# All methods and attributes a DataFrame supports can be checked in the [API documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html). Note that althought Pandas support Python's index operator `[]`, the recommended way to access values or ranges is to use `loc` for labels and `iloc` for positions. There's more information about it in the [Indexing and selecting data](https://pandas.pydata.org/docs/user_guide/indexing.html) chapter of Pandas documentation.

# %% [markdown]
# ### Data formats and compression
#
# Pandas can read and write multiple data formats, using `read_X` and `to_X` methods. Parameters are described in the [IO API documentation](https://pandas.pydata.org/pandas-docs/stable/io.html).
#
# One of the popular formats is [PyArrow](https://arrow.apache.org/docs/python/pandas.html), that has relatively good integration with Pandas. Normally, you will be interested to use a binary column-oriented format called [Feather](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#feather), created from the Arrow project.

# %%
data = pd.read_feather('./data/goog.feather')
data.dtypes
# Out:
# Date             str
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# Notice that in old versions of PyArrow, the index is lost when saving the data. You may want to create it again by doing:

# %%
data_indexed = data.set_index('Date')
data_indexed.head(1)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
#
#              Adj Close
# Date
# 2016-07-01  699.210022

# %% [markdown]
# You can also replace the index in-place, without creating a copy:

# %%
data.set_index('Date', inplace=True)
data.head(1)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
#
#              Adj Close
# Date
# 2016-07-01  699.210022

# %% [markdown]
# Similarly, you can write Feather files using `to_feather` function. Remember to drop the index first:

# %%
data = pd.read_csv("./data/goog.csv", index_col=0)
data.reset_index().to_feather('data/goog.feather')

# %% [markdown]
# Another widely use column-oriented format is [Parquet](https://parquet.apache.org/), a native Apache Hadoop ecosystem data storage format.

# %%
data.shape
# Out:
# (2989, 6)

# %%
data = pd.read_parquet("./data/goog.parquet")

# %% [markdown]
# Notice the size difference even with a small dataset

# %%
# !ls -lh ./data/goog.csv ./data/goog.parquet
# Out:
# -rw-rw-r-- 1 wac wac 215K Jun 19 17:07 ./data/goog.csv
# -rw-rw-r-- 1 wac wac 172K Jun 19 17:07 ./data/goog.parquet

# %% [markdown]
# Pandas also accepts compressed files, for instance in `gzip` format:

# %%
data = pd.read_csv('./data/goog.csv.gz')
data.head(1)
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 0  2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
#
#     Adj Close
# 0  699.210022

# %% [markdown]
# Remember that you don't need anything fancy to compress files, just use shell tools:
#
# ```
# $ gzip -9 data_file.csv
# ```

# %% [markdown]
# ## Accessing Data
#
# ### Column Indexing

# %% [markdown]
# By default, `read_csv` will not assume any index in the data. In our case we have a _natural_ index in the first column, so we can read the file again to make sure it's incorporated in the DataFrame:

# %%
data = pd.read_csv("./data/goog.csv", index_col=0)
data.head(2)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
# 2016-06-30  685.469971  692.320007  683.650024  692.099976  1590500
#
#              Adj Close
# Date
# 2016-07-01  699.210022
# 2016-06-30  692.099976

# %% [markdown]
# And then we can use range expressions to fetch _years_:

# %%
data["2016":"2015"].head(2)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-12-31  769.500000  769.500000  758.340027  758.880005  1489600
# 2015-12-30  776.599976  777.599976  766.900024  771.000000  1293300
#
#              Adj Close
# Date
# 2015-12-31  758.880005
# 2015-12-30  771.000000

# %% [markdown]
# Or _month_ ranges:

# %%
data["2016-05":"2015-04"].head(2)
# Out:
#                   Open        High         Low      Close   Volume  Adj Close
# Date
# 2016-04-29  690.700012  697.619995  689.000000  693.01001  2484300  693.01001
# 2016-04-28  708.260010  714.169983  689.549988  691.02002  2851100  691.02002

# %% [markdown]
# Notice that the index is set as an string instead of a timestamp. This could produce weird results when getting date ranges from the DataFrame. If you want to parse the dates, you have to set the flag `parse_dates=True` when reading the file.

# %%
data = pd.read_csv("./data/goog.csv", index_col=0, parse_dates=True)
data.index[0]
# Out:
# Timestamp('2016-07-01 00:00:00')

# %% [markdown]
# Then, for accessing a particular range remember the to use the `.loc` function instead of the array accessor:

# %%
data.loc['2016'].head(2)
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
# 2016-06-30  685.469971  692.320007  683.650024  692.099976  1590500
#
#              Adj Close
# Date
# 2016-07-01  699.210022
# 2016-06-30  692.099976

# %% [markdown]
# You can also use a date or a [Period](https://pandas.pydata.org/docs/reference/api/pandas.Period.html) object. Both are also sensible to the DataFrame ordering:

# %%
from datetime import datetime
data[datetime(2015,1,1):datetime(2016,1,1)]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume, Adj Close]
# Index: []

# %%
data.sort_index(ascending=True, inplace=True)
dfN = data[datetime(2015,1,1):datetime(2016,1,1)]
dfN.iloc[0:1].index, dfN.iloc[-1:].index
# Out:
# (DatetimeIndex(['2015-01-02'], dtype='datetime64[us]', name='Date', freq=None),
#  DatetimeIndex(['2015-12-31'], dtype='datetime64[us]', name='Date', freq=None))

# %%
dfQ = data.loc[str(pd.Period("2015"))]
dfQ.iloc[0:1].index, dfQ.iloc[-1:].index
# Out:
# (DatetimeIndex(['2015-01-02'], dtype='datetime64[us]', name='Date', freq=None),
#  DatetimeIndex(['2015-12-31'], dtype='datetime64[us]', name='Date', freq=None))

# %% [markdown]
# There's also a method called `.query` that would allow us to perform queries over the data:

# %%
data.query('Close > 600 & Volume > 33000000')
# Out:
#                  Open        High         Low       Close    Volume  \
# Date
# 2007-11-08  734.60125  734.891274  677.181165  693.841184  33148100
#
#              Adj Close
# Date
# 2007-11-08  346.574018

# %% [markdown]
# ### Adding or removing columns

# %%
data["Diff"] = data.Close - data.Open
data[["Open", "Close", "Diff"]].head(2)
# Out:
#                   Open       Close      Diff
# Date
# 2004-08-19  100.000168  100.340176  0.340008
# 2004-08-20  101.010175  108.310183  7.300008

# %%
del data["Diff"]
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='str')

# %% [markdown]
# ### Renaming a Column

# %%
data.rename(columns={'Adj Close': 'adj_close'})
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2004-08-19  100.000168  104.060182   95.960165  100.340176  44871300
# 2004-08-20  101.010175  109.080187  100.500174  108.310183  22942800
# 2004-08-23  110.750191  113.480193  109.050183  109.400185  18342800
# 2004-08-24  111.240189  111.600192  103.570177  104.870176  15319700
# 2004-08-25  104.960181  108.000187  103.880180  106.000184   9232100
# ...                ...         ...         ...         ...       ...
# 2016-06-27  671.000000  672.299988  663.283997  668.260010   2629000
# 2016-06-28  678.969971  680.330017  673.000000  680.039978   2116600
# 2016-06-29  683.000000  687.429016  681.409973  684.109985   1928500
# 2016-06-30  685.469971  692.320007  683.650024  692.099976   1590500
# 2016-07-01  692.200012  700.650024  692.130005  699.210022   1342700
#
#              adj_close
# Date
# 2004-08-19   50.119968
# 2004-08-20   54.100990
# 2004-08-23   54.645447
# 2004-08-24   52.382705
# 2004-08-25   52.947145
# ...                ...
# 2016-06-27  668.260010
# 2016-06-28  680.039978
# 2016-06-29  684.109985
# 2016-06-30  692.099976
# 2016-07-01  699.210022
#
# [2989 rows x 6 columns]

# %% [markdown]
# ### Parsing Dates
#
# You would normally use `parse_dates=True` or `parse_dates=[0]` to automatically process dates when reading files. In some cases you would like to perform that manually by using `pd.to_datetime` function:

# %%
df2 = pd.read_csv("./data/goog.csv")
df2['Month'] = pd.to_datetime(df2['Date']).dt.month
df2.head(2)
# Out:
#          Date        Open        High         Low       Close   Volume  \
# 0  2016-07-01  692.200012  700.650024  692.130005  699.210022  1342700
# 1  2016-06-30  685.469971  692.320007  683.650024  692.099976  1590500
#
#     Adj Close  Month
# 0  699.210022      7
# 1  692.099976      6

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2989 entries, 0 to 2988
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2989 non-null   str
#  1   Open       2989 non-null   float64
#  2   High       2989 non-null   float64
#  3   Low        2989 non-null   float64
#  4   Close      2989 non-null   float64
#  5   Volume     2989 non-null   int64
#  6   Adj Close  2989 non-null   float64
#  7   Month      2989 non-null   int32
# dtypes: float64(5), int32(1), int64(1), str(1)
# memory usage: 204.5 KB

# %% [markdown]
# ### Grouping

# %%
df2.groupby(df2['Month'])['Close'].mean()
# Out:
# Month
# 1     583.353097
# 2     572.136671
# 3     557.874017
# 4     527.056556
# 5     531.708374
# 6     531.205082
# 7     538.988607
# 8     519.061782
# 9     505.104736
# 10    540.488037
# 11    565.204085
# 12    576.999005
# Name: Close, dtype: float64

# %% [markdown]
# ### Multi-Indexes
#
# Pandas is able to treat data that has indexes in multiple levels. For instance, the `prices.csv` data set has two initial columns with the stock symbol and the date of the prices. That's described in [Hierarchical indexing](https://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced-hierarchical) documentation.

# %%
pd.read_csv('./data/prices.csv').head(2)
# Out:
#   Symbol        Date  Adj Close      Close       High     Low       Open  \
# 0   aapl  2010-01-04   6.535084   7.643214   7.660714   7.585   7.622500
# 1   msft  2010-01-04  23.800220  30.950001  31.100000  30.590  30.620001
#
#         Volume
# 0  493729600.0
# 1   38409100.0

# %% [markdown]
# We can easily tell Pandas that first two columns are the index by using the `index_col` parameter. Let's create a data frame named `prices`, containing price data for several stocks in a time range.

# %%
prices = pd.read_csv('./data/prices.csv', index_col=[0,1])
prices.head(5)
# Out:
#                      Adj Close        Close         High          Low  \
# Symbol Date
# aapl   2010-01-04     6.535084     7.643214     7.660714     7.585000
# msft   2010-01-04    23.800220    30.950001    31.100000    30.590000
# goog   2010-01-04   312.204773   312.204773   313.579620   310.954468
# ^GSPC  2010-01-04  1132.989990  1132.989990  1133.869995  1116.560059
# aapl   2010-01-05     6.546383     7.656429     7.699643     7.616071
#
#                           Open        Volume
# Symbol Date
# aapl   2010-01-04     7.622500  4.937296e+08
# msft   2010-01-04    30.620001  3.840910e+07
# goog   2010-01-04   312.304413  3.927065e+06
# ^GSPC  2010-01-04  1116.560059  3.991400e+09
# aapl   2010-01-05     7.664286  6.019048e+08

# %%
prices.index
# Out:
# MultiIndex([( 'aapl', '2010-01-04'),
#             ( 'msft', '2010-01-04'),
#             ( 'goog', '2010-01-04'),
#             ('^GSPC', '2010-01-04'),
#             ( 'aapl', '2010-01-05'),
#             ( 'msft', '2010-01-05'),
#             ( 'goog', '2010-01-05'),
#             ('^GSPC', '2010-01-05'),
#             ( 'aapl', '2010-01-06'),
#             ( 'msft', '2010-01-06'),
#             ...
#             ( 'aapl', '2022-06-30'),
#             ( 'msft', '2022-06-30'),
#             ( 'goog', '2022-06-30'),
#             ( 'tsla', '2022-06-30'),
#             ('^GSPC', '2022-06-30'),
#             ( 'aapl', '2022-07-01'),
#             ( 'msft', '2022-07-01'),
#             ( 'goog', '2022-07-01'),
#             ( 'tsla', '2022-07-01'),
#             ('^GSPC', '2022-07-01')],
#            names=['Symbol', 'Date'], length=15608)

# %% [markdown]
# To query for a particular index, you can use `get_level_values` function and `isin`:

# %%
msft = prices[prices.index.get_level_values('Symbol').isin(['msft'])]
msft.head()
# Out:
#                    Adj Close      Close       High        Low       Open  \
# Symbol Date
# msft   2010-01-04  23.800220  30.950001  31.100000  30.590000  30.620001
#        2010-01-05  23.807911  30.959999  31.100000  30.639999  30.850000
#        2010-01-06  23.661804  30.770000  31.080000  30.520000  30.879999
#        2010-01-07  23.415728  30.450001  30.700001  30.190001  30.629999
#        2010-01-08  23.577215  30.660000  30.879999  30.240000  30.280001
#
#                        Volume
# Symbol Date
# msft   2010-01-04  38409100.0
#        2010-01-05  49749600.0
#        2010-01-06  58182400.0
#        2010-01-07  50559700.0
#        2010-01-08  51197400.0

# %% [markdown]
# Also, `query` method is also available for multi-indexes:

# %%
prices.query('Symbol == "msft"').head()
# Out:
#                    Adj Close      Close       High        Low       Open  \
# Symbol Date
# msft   2010-01-04  23.800220  30.950001  31.100000  30.590000  30.620001
#        2010-01-05  23.807911  30.959999  31.100000  30.639999  30.850000
#        2010-01-06  23.661804  30.770000  31.080000  30.520000  30.879999
#        2010-01-07  23.415728  30.450001  30.700001  30.190001  30.629999
#        2010-01-08  23.577215  30.660000  30.879999  30.240000  30.280001
#
#                        Volume
# Symbol Date
# msft   2010-01-04  38409100.0
#        2010-01-05  49749600.0
#        2010-01-06  58182400.0
#        2010-01-07  50559700.0
#        2010-01-08  51197400.0

# %% [markdown]
# Once filtering is done, you might want to drop `Symbol` index:

# %%
msft.index = msft.index.droplevel(0)
msft.head()
# Out:
#             Adj Close      Close       High        Low       Open      Volume
# Date
# 2010-01-04  23.800220  30.950001  31.100000  30.590000  30.620001  38409100.0
# 2010-01-05  23.807911  30.959999  31.100000  30.639999  30.850000  49749600.0
# 2010-01-06  23.661804  30.770000  31.080000  30.520000  30.879999  58182400.0
# 2010-01-07  23.415728  30.450001  30.700001  30.190001  30.629999  50559700.0
# 2010-01-08  23.577215  30.660000  30.879999  30.240000  30.280001  51197400.0

# %%
aapl = prices[prices.index.get_level_values('Symbol').isin(['aapl'])]
aapl.index = aapl.index.droplevel(0)
aapl.head()
# Out:
#             Adj Close     Close      High       Low      Open       Volume
# Date
# 2010-01-04   6.535084  7.643214  7.660714  7.585000  7.622500  493729600.0
# 2010-01-05   6.546383  7.656429  7.699643  7.616071  7.664286  601904800.0
# 2010-01-06   6.442255  7.534643  7.686786  7.526786  7.656429  552160000.0
# 2010-01-07   6.430345  7.520714  7.571429  7.466071  7.562500  477131200.0
# 2010-01-08   6.473095  7.570714  7.571429  7.466429  7.510714  447610800.0

# %% [markdown]
# All that operations can be simplified by using `loc` function

# %%
prices.loc['aapl'].head()
# Out:
#             Adj Close     Close      High       Low      Open       Volume
# Date
# 2010-01-04   6.535084  7.643214  7.660714  7.585000  7.622500  493729600.0
# 2010-01-05   6.546383  7.656429  7.699643  7.616071  7.664286  601904800.0
# 2010-01-06   6.442255  7.534643  7.686786  7.526786  7.656429  552160000.0
# 2010-01-07   6.430345  7.520714  7.571429  7.466071  7.562500  477131200.0
# 2010-01-08   6.473095  7.570714  7.571429  7.466429  7.510714  447610800.0

# %% [markdown]
# ### Stacking
#
# Using `stack` and `unstack` you can easily convert multi-indexed data into different columns. Notice that in the following example, we're using column `1` as the first one in the index.

# %%
prices = pd.read_csv('./data/prices.csv', index_col=[1,0], usecols=[0,1,3], parse_dates=[1])
prices.head(5)
# Out:
#                          Close
# Date       Symbol
# 2010-01-04 aapl       7.643214
#            msft      30.950001
#            goog     312.204773
#            ^GSPC   1132.989990
# 2010-01-05 aapl       7.656429

# %%
prices.unstack().head(2)
# Out:
#                  Close
# Symbol           ^GSPC      aapl        goog       msft tsla
# Date
# 2010-01-04  1132.98999  7.643214  312.204773  30.950001  NaN
# 2010-01-05  1136.52002  7.656429  310.829926  30.959999  NaN

# %% [markdown]
# We recommend to read the Pandas documentation about [pivoting data](https://pandas.pydata.org/docs/user_guide/reshaping.html#pivot-tables).

# %% [markdown]
# ## Series
#
# All columns in the previous DataFrame are defined as [_Series_](https://pandas.pydata.org/pandas-docs/stable/dsintro.html#series). A Serie is a data bag indexed by date, in most cases.

# %%
data.Close[:2]
# Out:
# Date
# 2004-08-19    100.340176
# 2004-08-20    108.310183
# Name: Close, dtype: float64

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
type(data.Close)
# Out:
# pandas.Series

# %% [markdown]
# [Series API](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html#pandas.Series) has multiple methods, but one of the most interesting ones is the `describe` one:

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  2989.000000  2989.000000  2989.000000  2989.000000  2.989000e+03
# mean    545.818013   551.077358   539.992664   545.555584  8.722729e+06
# std     196.117817   196.778854   195.146794   196.002935  8.522202e+06
# min      99.190173   101.740174    95.960165   100.010169  7.900000e+03
# 25%     435.300734   441.040745   428.490746   435.110754  3.489900e+06
# 50%     538.082440   542.002431   532.971985   537.359985  5.977000e+06
# 75%     626.700012   631.841061   620.511074   625.651065  1.144020e+07
# max    1226.802152  1228.882066  1218.602083  1220.172036  8.254150e+07
#
#          Adj Close
# count  2989.000000
# mean    331.062308
# std     170.024496
# min      49.955130
# 25%     217.338039
# 50%     282.058429
# 75%     439.426336
# max     776.599976

# %%
data.Close.describe()
# Out:
# count    2989.000000
# mean      545.555584
# std       196.002935
# min       100.010169
# 25%       435.110754
# 50%       537.359985
# 75%       625.651065
# max      1220.172036
# Name: Close, dtype: float64

# %% [markdown]
# ### Sampling

# %%
data.Close.sample(n=3)
# Out:
# Date
# 2014-07-03    584.732656
# 2014-12-29    530.332426
# 2005-01-24    180.720314
# Name: Close, dtype: float64

# %% [markdown]
# There are two interesting parameters to separate training data from model testing data:
# - Use `frac` to get the % of items from the whole set to retrieve
# - If you want sets to be consistent between runs, use `random_state`.

# %%
data.Close.sample(frac=0.003, random_state=1)
# Out:
# Date
# 2011-03-02     600.791038
# 2015-10-29     716.919983
# 2006-02-24     377.400645
# 2010-12-17     590.801018
# 2014-01-14    1149.402027
# 2009-01-22     306.500511
# 2006-05-22     370.950644
# 2008-02-04     495.430864
# 2012-08-13     660.011122
# Name: Close, dtype: float64

# %% [markdown]
# There are also two functions to retrieve the largest and smallest values of a set:

# %%
data.Close.nlargest(3)
# Out:
# Date
# 2014-02-26    1220.172036
# 2014-02-25    1220.002089
# 2014-03-06    1219.612082
# Name: Close, dtype: float64

# %% [markdown]
# ### Querying

# %%
data[data["Close"] > 1220]
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2014-02-25  1215.942121  1224.502055  1210.422109  1220.002089  2888100
# 2014-02-26  1224.002141  1228.882066  1213.762102  1220.172036  3979100
#
#              Adj Close
# Date
# 2014-02-25  609.391653
# 2014-02-26  609.476541

# %%
data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='str')

# %%
data = data.rename(columns={'Adj Close': 'adj_close'})

# %%
data[data.adj_close > 726]
# Out:
#                   Open        High         Low       Close   Volume  \
# Date
# 2015-11-04  722.000000  733.099976  721.900024  728.109985  1706700
# 2015-11-05  729.469971  739.479980  729.469971  731.250000  1861600
# 2015-11-06  731.500000  735.409973  727.010010  733.760010  1511600
# 2015-11-10  724.400024  730.590027  718.500000  728.320007  1608000
# 2015-11-11  732.460022  741.000000  730.229980  735.400024  1366400
# ...                ...         ...         ...         ...      ...
# 2016-05-31  731.739990  739.729980  731.260010  735.719971  2119900
# 2016-06-01  734.530029  737.210022  730.659973  734.150024  1250800
# 2016-06-02  732.500000  733.020020  724.169983  730.400024  1337600
# 2016-06-08  723.960022  728.570007  720.580017  728.280029  1582100
# 2016-06-09  722.869995  729.539978  722.335999  728.580017   985900
#
#              adj_close
# Date
# 2015-11-04  728.109985
# 2015-11-05  731.250000
# 2015-11-06  733.760010
# 2015-11-10  728.320007
# 2015-11-11  735.400024
# ...                ...
# 2016-05-31  735.719971
# 2016-06-01  734.150024
# 2016-06-02  730.400024
# 2016-06-08  728.280029
# 2016-06-09  728.580017
#
# [82 rows x 6 columns]

# %%
data.query("Close > 1220")
# Out:
#                    Open         High          Low        Close   Volume  \
# Date
# 2014-02-25  1215.942121  1224.502055  1210.422109  1220.002089  2888100
# 2014-02-26  1224.002141  1228.882066  1213.762102  1220.172036  3979100
#
#              adj_close
# Date
# 2014-02-25  609.391653
# 2014-02-26  609.476541

# %% [markdown]
# ### Masking

# %% [markdown]
# There's also two functions, `mask` and `where`, that you can use to discard or include values. In this case it's being is used to filter out values greater than 685, and fill the values with -42. If fill value is omited, `NaN` is used instead.

# %%
data.Close.where(lambda x: x > 685, -42).head(5)
# Out:
# Date
# 2004-08-19   -42.0
# 2004-08-20   -42.0
# 2004-08-23   -42.0
# 2004-08-24   -42.0
# 2004-08-25   -42.0
# Name: Close, dtype: float64

# %% [markdown]
#  Notice that `mask` and `where` do the opposite:

# %%
data.Close.mask(lambda x: x > 685, -42).head(5)
# Out:
# Date
# 2004-08-19    100.340176
# 2004-08-20    108.310183
# 2004-08-23    109.400185
# 2004-08-24    104.870176
# 2004-08-25    106.000184
# Name: Close, dtype: float64

# %% [markdown]
# ### Pipes
#
# It is possible to apply a function to every value of the Series:

# %%
def double(x):
    return x * 2

data.Close.pipe(double).pipe(lambda x: x + 5).head(2)
# Out:
# Date
# 2004-08-19    205.680352
# 2004-08-20    221.620366
# Name: Close, dtype: float64

# %% [markdown]
# The `pipe` operation can be also applied to DataFrames:

# %%
def double_close(df):
    df['Double Close'] = df['Close'] * 2
    return df

data.pipe(double_close).head(2)
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2004-08-19  100.000168  104.060182   95.960165  100.340176  44871300
# 2004-08-20  101.010175  109.080187  100.500174  108.310183  22942800
#
#             adj_close  Double Close
# Date
# 2004-08-19  50.119968    200.680352
# 2004-08-20  54.100990    216.620366

# %% [markdown]
# ### Apply
#
# The `apply` method allows to execute arbitrary functions over a Series.

# %%
data.Close['2016'].apply(lambda x: x * 2)
# Out:
# Date
# 2016-01-04    1483.680054
# 2016-01-05    1485.160034
# 2016-01-06    1487.239990
# 2016-01-07    1452.780030
# 2016-01-08    1428.939942
#                  ...
# 2016-06-27    1336.520020
# 2016-06-28    1360.079956
# 2016-06-29    1368.219970
# 2016-06-30    1384.199952
# 2016-07-01    1398.420044
# Name: Close, Length: 126, dtype: float64

# %% [markdown]
# It can also be applied to a DataFrame directly, by selecting the axis - normally `0` for the index and `1` for the DataFrame columns.

# %%
import numpy as np
data.apply(np.mean, axis=0)
# Out:
# Open         5.458180e+02
# High         5.510774e+02
# Low          5.399927e+02
# Close        5.455556e+02
# Volume       8.722729e+06
# adj_close    3.310623e+02
# dtype: float64

# %%
data.apply(np.mean, axis=1)
# Out:
# Date
# 2004-08-19    7.478625e+06
# 2004-08-20    3.823879e+06
# 2004-08-23    3.057216e+06
# 2004-08-24    2.553364e+06
# 2004-08-25    1.538763e+06
#                   ...
# 2016-06-27    4.387239e+05
# 2016-06-28    3.533321e+05
# 2016-06-29    3.219867e+05
# 2016-06-30    2.656576e+05
# 2016-07-01    2.243639e+05
# Length: 2989, dtype: float64

# %% [markdown]
# ### Reading directly into a series
#
# Instead of reading files as `DataFrames`, it's possible to read a `Series` directly, using column 0 as date, and colum 4 as the `Series` value. Do not forget to apply the `.squeze` function afterwards.

# %%
series = pd.read_csv("./data/goog.csv", header=0, index_col=0, usecols=[0, 4], parse_dates=True).squeeze()
series.head()
# Out:
# Date
# 2016-07-01    699.210022
# 2016-06-30    692.099976
# 2016-06-29    684.109985
# 2016-06-28    680.039978
# 2016-06-27    668.260010
# Name: Close, dtype: float64

# %% [markdown]
# ---
#
# ### Exercise 1.1
#
# Read file `prices.csv` and filter symbol `tsla`. Select 90% of `Close` column for training and reserve 10% for model later checking. Try to randomise data picked.
#
# You may want to check [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/).
#
# ### Exercise 1.2
#
# From `prices.csv` file, read `msft` data and write it as a Feather file in `data/msft.feather`.
#
# ### Exercise 1.3
#
# Add a boolean column to previous `msft` data frame indicating if trades open with values greater than 100.
#
# ### Exercise 1.4
#
# Look in Pandas documentation for __styling functions__ and mark in red the `close` values below 30.
#
# ---

# %% [markdown]
# ## Time-Series
#
# Our series can be [resampled](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.resample.html) to months, using mean close price for each one.
#
# - M: Months
# - Q: Quarters
# - A: Years
#
# The `resample` function just returns an object represeting the resampling. We have to pick one of the many functions to extract the value for each new of the rows generated (months, quarters or year rows). The available offset strings can be found [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects).

# %%
series = pd.read_csv("./data/goog.csv", header=0, index_col=0, usecols=[0, 4], parse_dates=True).squeeze()
series.resample("A")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6213, in pandas._libs.tslibs.offsets._get_offset()
# -> 6213 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'A'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File pandas/_libs/tslibs/offsets.pyx:6344, in pandas._libs.tslibs.offsets.to_offset()
# -> 6344 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/offsets.pyx:6219, in pandas._libs.tslibs.offsets._get_offset()
# -> 6219 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
# -> 6137 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Invalid frequency: A. Failed to parse with error message: KeyError('A'). Did you mean Y?
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 2
#       1 series = pd.read_csv("./data/goog.csv", header=0, index_col=0, usecols=[0, 4], parse_dates=True).squeeze()
# ----> 2 series.resample("A")
#
# File ~/master/financial-analysis/financial-analysis-svc/.venv/lib/python3.12/site-packages/pandas/core/generic.py:9423, in NDFrame.resample(self, rule, closed, label, convention, on, level, origin, offset, group_keys)
#    9419         Freq: 17min, dtype: int64
#    9420         """
#    9421         from pandas.core.resample import get_resampler
#    9422
# -> 9423         return get_resampler(
#    9424             cast("Series | DataFrame", self),
#    9425             freq=rule,
#    9426             label=label,
#
# File ~/master/financial-analysis/financial-analysis-svc/.venv/lib/python3.12/site-packages/pandas/core/resample.py:2334, in get_resampler(obj, **kwds)
#    2330 def get_resampler(obj: Series | DataFrame, **kwds) -> Resampler:
#    2331     """
#    2332     Create a TimeGrouper and return our resampler.
#    2333     """
# -> 2334     tg = TimeGrouper(obj, **kwds)  # type: ignore[arg-type]
#    2335     return tg._get_resampler(obj)
#
# File ~/master/financial-analysis/financial-analysis-svc/.venv/lib/python3.12/site-packages/pandas/core/resample.py:2420, in TimeGrouper.__init__(self, obj, freq, key, closed, label, how, fill_method, limit, convention, origin, offset, group_keys, **kwargs)
#    2418     freq = to_offset(freq, is_period=True)
#    2419 else:
# -> 2420     freq = to_offset(freq)
#    2422 if not isinstance(freq, Tick):
#    2423     if offset is not None:
#
# File pandas/_libs/tslibs/offsets.pyx:6229, in pandas._libs.tslibs.offsets.to_offset()
# -> 6229 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/offsets.pyx:6352, in pandas._libs.tslibs.offsets.to_offset()
# -> 6352 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/offsets.pyx:6137, in pandas._libs.tslibs.offsets.raise_invalid_freq()
# -> 6137 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Invalid frequency: A. Failed to parse with error message: ValueError("Invalid frequency: A. Failed to parse with error message: KeyError('A'). Did you mean Y?") Did you mean Y?

# %%
series

# %% [markdown]
# ### Padding
#
# First thing we can do is to get the latest value known in each range, `ffill` method. Don't use `pad` or `fillna(method="ffill")` functions, since they are deprecated.

# %%
series['2004-12-31']

# %% [markdown]
# For brevity, there's a function called `ffill` that calls to `fillna` internally:

# %%
series.resample("A").ffill().head()

# %% [markdown]
# ### Computing range mean, min or max values
#
# And we can also get the mean values for each range. Instead of `fillna`, use `mean` function:

# %%
series["2004"].mean()

# %%
series.resample("A").mean().head()

# %%
series.resample("A").max().head()

# %% [markdown]
# Or even `sum` all the values in a range - although in this case it doesn't make too much sense.

# %%
series.resample("A").sum().head()

# %% [markdown]
# ### Ploting resampled series for better understanding

# %%
series.head()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
series.plot(figsize=(10,5))
series.resample("M").mean().plot(linewidth=3)
plt.show()

# %% [markdown]
# ### OHLC: Open, High, Low, Close
#
# A very interesting function is `ohlc`, that computes several values for a date range.

# %%
series.resample("A").ohlc()

# %% [markdown]
# ### Custom ranges
#
# Every two years:

# %%
series.resample("2AS").mean().head()

# %% [markdown]
# There is more information for those magic strings like `2AS in [the documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects).

# %% [markdown]
# ### Upsampling
#
# Apart of grouping data (or _downsampling_) we can also calculate interpolated values. For instence, we're going to calculate values for each quarter, using `"Q"` or `"4M"` parameters.
#
# First we need to get the data downsampled to year values, using latest one.

# %%
msft_year = series.resample("AS").mean()
msft_year

# %% [markdown]
# Then we can interpolate some values. Normally you would use `ffill`, optionally setting the maximum number of rows to fill before stopping propagation and filling with `NaN`.

# %%
rs = msft_year.resample("Q")
max_propagated = 2
pd.DataFrame({ 'mean': rs.mean(), 'ffill': rs.ffill(), 
              'ffill_max': rs.ffill(max_propagated) })[:9]

# %% [markdown]
# ---
#
# ### Exercise 1.5
#
# Read CSV data for Tesla `tsla` directly into a `Series` and compute _closing_ values for each quarter.
#
# ---

# %% [markdown]
# ## Cookbook

# %% [markdown]
# ### Combining Series into new DataFrame

# %%
msft_aapl = pd.DataFrame({ 'msft': msft.Close, 'aapl': aapl.Close })
msft_aapl[:3]

# %% [markdown]
# By default it uses closed ranges.

# %% [markdown]
# ### Column projections

# %%
from sample_data import stock_prices
aapl = stock_prices('aapl')

# %%
aapl

# %%
aapl.loc[:,"Year"] = pd.to_datetime(aapl.index).map(lambda d: d.year)
aapl[:2]

# %% [markdown]
# ### Using custom indexes

# %%
dates = pd.date_range('2015-10', '2016-02', freq='M')
dates

# %%
from pandas import Series
Series(series, index=dates)

# %% [markdown]
# ### Install packages in Colab Notebooks
#
# Very simple, use `pip` or `conda`, by appending a `!` in a cell for executing in a shell
#
# `!pip install package_name`.
